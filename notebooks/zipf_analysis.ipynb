# %% [markdown]
# # Section 1
#
#   * here we read the text (both of the texts) then we split them into words

# %%
# read Text-1.txt file
with open('Text-1.txt', 'r', encoding='ISO-8859-1') as f: text1 = f.read()

# first show the number of characters in the file
print('Number of characters in Text-1.txt file:', len(text1))

# second show the number of words in the file
words = text1.split()
print('Number of words in Text-1.txt file:', len(words))

# convert all words to lower case
words = [word.lower() for word in words]

# third show the number of lines in the file
lines = text1.split('\n')
print('Number of lines in Text-1.txt file:', len(lines))
# Out:
# Number of characters in Text-1.txt file: 955718
# Number of words in Text-1.txt file: 159985
# Number of lines in Text-1.txt file: 14347

# %%
# read Text-2.txt file
with open('Text-2.txt', 'r', encoding='ISO-8859-1') as f: text2 = f.read()

# first show the number of characters in the file
print('Number of characters in Text-2.txt file:', len(text2))

# second show the number of words in the file
words = text2.split()
print('Number of words in Text-2.txt file:', len(words))

# third show the number of lines in the file
lines = text2.split('\n')
print('Number of lines in Text-2.txt file:', len(lines))
# Out:
# Number of characters in Text-2.txt file: 947543
# Number of words in Text-2.txt file: 159150
# Number of lines in Text-2.txt file: 14347

# %% [markdown]
# # Section 2
#   * Here we count each word in word list then save it to dict.

# %%
# this is the list of all words that we want to count
words_to_count = [
  'the',
  'eye',
  'of',
  'existence',
  'hair',
  'and',
  'nature',
  'month',
  'head',
  'darwin',
  'size',
  'touch',
  'second',
  'conclusion',
  'revolution',
  'muscles',
  'necessity',
  'public',
  'body',
  'Within',
  'to',
  'in',
  'distribution',
  'words',
]

# count the number of words in Text-1.txt file
text1_count = {word: text1.count(word) for word in words_to_count}
print(text1_count)

# count the number of 'the' in Text-2.txt file
text2_count = {word: text2.count(word) for word in words_to_count}
print(text2_count)
# Out:
# {'the': 14747, 'eye': 62, 'of': 8302, 'existence': 66, 'hair': 20, 'and': 5311, 'nature': 246, 'month': 6, 'head': 49, 'darwin': 0, 'size': 76, 'touch': 7, 'second': 75, 'conclusion': 39, 'revolution': 4, 'muscles': 4, 'necessity': 6, 'public': 2, 'body': 52, 'Within': 1, 'to': 4700, 'in': 14610, 'distribution': 53, 'words': 9}
# {'the': 15404, 'eye': 62, 'of': 8325, 'existence': 75, 'hair': 21, 'and': 5386, 'nature': 264, 'month': 6, 'head': 49, 'darwin': 4, 'size': 76, 'touch': 7, 'second': 82, 'conclusion': 41, 'revolution': 4, 'muscles': 4, 'necessity': 6, 'public': 3, 'body': 52, 'Within': 0, 'to': 4744, 'in': 14988, 'distribution': 60, 'words': 9}

# %% [markdown]
# # Section 3
#   * convert it to Pandas dataframe to show it in tables

# %%
import pandas as pd

# load the data to a DataFrame
df = pd.DataFrame([text1_count, text2_count], index=['Text-1', 'Text-2'])

# show the DataFrame
df
# Out:
#           the  eye    of  existence  hair   and  nature  month  head  darwin  \
# Text-1  14747   62  8302         66    20  5311     246      6    49       0
# Text-2  15404   62  8325         75    21  5386     264      6    49       4
#
#         ...  revolution  muscles  necessity  public  body  Within    to  \
# Text-1  ...           4        4          6       2    52       1  4700
# Text-2  ...           4        4          6       3    52       0  4744
#
#            in  distribution  words
# Text-1  14610            53      9
# Text-2  14988            60      9
#
# [2 rows x 24 columns]

# %%
# Part A) show the word graph

# for Text-1.txt file
text1_df = pd.DataFrame(text1_count.items(), columns=['word', 'count'])
# sort the DataFrame by count
text1_df = text1_df.sort_values(by='count', ascending=False)
# adding rank column
text1_df['rank'] = range(1, len(text1_df) + 1)
# sort the DataFrame by index
text1_df = text1_df.sort_index()
# show the DataFrame
text1_df
# Out:
#             word  count  rank
# 0            the  14747     1
# 1            eye     62    10
# 2             of   8302     3
# 3      existence     66     9
# 4           hair     20    15
# 5            and   5311     4
# 6         nature    246     6
# 7          month      6    18
# 8           head     49    13
# 9         darwin      0    24
# 10          size     76     7
# 11         touch      7    17
# 12        second     75     8
# 13    conclusion     39    14
# 14    revolution      4    20
# 15       muscles      4    21
# 16     necessity      6    19
# 17        public      2    22
# 18          body     52    12
# 19        Within      1    23
# 20            to   4700     5
# 21            in  14610     2
# 22  distribution     53    11
# 23         words      9    16

# %%
# part A) show the word graph

# for Text-2.txt file
text2_df = pd.DataFrame(text2_count.items(), columns=['word', 'count'])
# sort the DataFrame by count
text2_df = text2_df.sort_values(by='count', ascending=False)
# adding rank column
text2_df['rank'] = range(1, len(text2_df) + 1)
# sort the DataFrame by index
text2_df = text2_df.sort_index()
# show the DataFrame
text2_df
# Out:
#             word  count  rank
# 0            the  15404     1
# 1            eye     62    10
# 2             of   8325     3
# 3      existence     75     9
# 4           hair     21    15
# 5            and   5386     4
# 6         nature    264     6
# 7          month      6    18
# 8           head     49    13
# 9         darwin      4    21
# 10          size     76     8
# 11         touch      7    17
# 12        second     82     7
# 13    conclusion     41    14
# 14    revolution      4    20
# 15       muscles      4    22
# 16     necessity      6    19
# 17        public      3    23
# 18          body     52    12
# 19        Within      0    24
# 20            to   4744     5
# 21            in  14988     2
# 22  distribution     60    11
# 23         words      9    16

# %% [markdown]
# # Section 4
#   * Here we plot the distribution

# %%
# part B) show the word graph

# for Text-1.txt file
import matplotlib.pyplot as plt

# create a figure of two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# plot the bar chart for Text-1.txt file
ax[0].bar(text1_df['word'], text1_df['count'])
ax[0].set_title('Text-1.txt file')

# plot the bar chart for Text-2.txt file
ax[1].bar(text2_df['word'], text2_df['count'])
ax[1].set_title('Text-2.txt file')

# log scale for y-axis
ax[0].set_yscale('log')
ax[1].set_yscale('log')

# show the figure
plt.show()

# %%
# part B) show the word graph
# for Text-2.txt file
# create a figure
fig, ax = plt.subplots(figsize=(15, 5))

# plot the bar chart for Text-2.txt file
ax.bar(text2_df['word'], text2_df['count'])

# log scale for y-axis
ax.set_yscale('log')

# smaller font size for x-axis labels
plt.xticks(fontsize=6)

# show the figure
plt.show()

# %% [markdown]
# # Section 5
#   * Here we plot the sorted value to compare it to Zipf's law

# %%
# part B) show the word graph

# for Text-2.txt file with x as rank and y as count
# create a figure
fig, ax = plt.subplots(figsize=(15, 5))

# title of the figure
ax.set_title('Word Graph for Text-2.txt file')

# sort the DataFrame by rank
text2_df = text2_df.sort_values(by='rank')

# plot the bar chart for Text-2.txt file
ax.plot(text2_df['rank'], text2_df['count'])
# ax.bar(text2_df['rank'], text2_df['count'])

# log scale for y-axis
ax.set_yscale('log')
# set labels for y-axis
ax.set_ylabel('Count')

# log scale for x-axis
ax.set_xscale('log')
# set labels for x-axis
ax.set_xlabel('Rank')

# show the figure
plt.show()

# %%
# zipf's law frequency = 1/(rank + b)^a
freq = lambda rank, a, b: 1 / (rank + b) ** a
# real frequency = count / total number of words
real_freq = lambda count, total: count / total

# calculate the frequency for Text-2.txt file
text2_df['freq'] = freq(text2_df['rank'], 3, 2.7) # a = 3, b = 2.7
# calculate the real frequency for Text-2.txt file
text2_df['real_freq'] = real_freq(text2_df['count'], len(words))

# plot the frequency and real frequency
fig, ax = plt.subplots(figsize=(15, 5))

# plot the frequency
ax.plot(text2_df['rank'], text2_df['freq'], label='Zipf\'s law')
# plot the real frequency
ax.plot(text2_df['rank'], text2_df['real_freq'], label='Real frequency')

# set labels for x-axis and y-axis
ax.set_xlabel('Rank')
ax.set_ylabel('Frequency')

# set the title of the figure
ax.set_title('Zipf\'s law vs Real frequency')

# log scale for x-axis and y-axis
ax.set_xscale('log')
ax.set_yscale('log')

# show the legend
ax.legend()

# show the figure
plt.show()

# %% [markdown]
# # Data Analysis
# #
# ## Part A) Word Graph
# ***
# ### 1. Most Frequent Words:
#    - The word "the" occurs most frequently with 15,404 occurrences.
#    - Other common words include "and" (5,386), "of" (8,325), and "in" (14,988).
#
# ### 2. Less Frequent Words:
#    - Words like "existence," "nature," "month," and "head" have moderate frequencies.
#    - Some words like "darwin," "revolution," and "muscles" occur with lower frequencies.
#
# ### 3. Uncommon Words:
#    - Words such as "public," "conclusion," and "words" have relatively lower frequencies.
#
# ### 4. Special Cases:
#    - The word "Within" has a frequency of 0, indicating that it doesn't occur in the dataset.
#
# ### 5. Total Word Count:
#    - The total number of words in the dataset can be calculated by summing up all the frequencies.
#
# ### 6. Distribution Characteristics:
#    - The dataset seems to represent a diverse set of words, with varying frequencies. This distribution can be further analyzed for insights into the underlying text or corpus.
#
# ### 7. Contextual Considerations:
#    - The meaning and significance of the words depend on the context of the text or corpus from which the data is derived.
# #
# ## Part B) Zipf's Law graph
# ***
#
# First we have Zipf's Law formula:
#
# $$f = \frac{1}{(r + b)^a}$$
#
# Then we have the real frequency formula:
#
# $$f = \frac{count}{total}$$
#
# According to the Zipf's Law, the frequency of a word is inversely proportional to its rank. This means that the most frequent word will occur twice as often as the second most frequent word, three times as often as the third most frequent word, and so on. This is clearly visible in the graph, where the frequency of the most frequent word is much higher than the frequency of the second most frequent word, and so on.
#
# Then we have this two parameters $a$ and $b$, which are used to adjust the curve of the graph. The value of $a$ is usually between 1 and 2, and the value of $b$ is usually between 2 and 3. The value of $a$ determines the slope of the curve, and the value of $b$ determines the position of the curve. And now I set $a = 3$ and $b = 2.7$. to better fit the data.
